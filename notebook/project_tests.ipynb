# %% [markdown]
# # Projet LU2IN013: Exploration des Systèmes de Rating
# Ce projet explore les systèmes de classement tels que Elo, Glicko et Glicko-2.
# L'objectif est de simuler des rencontres entre joueurs, d'analyser les distributions des compétences et des classements Elo, et de visualiser les résultats.
#
# ## Classes Utilisées
# - **Joueur**: Modélise un joueur avec des compétences, un historique des parties et un classement Elo.
# - **Jeu**: Représente un jeu avec un taux de hasard influençant les résultats.
# - **Outils**: Contient des fonctions pour calculer les probabilités de victoire et mettre à jour les classements Elo.
# - **Tournoi**: Implémente des tournois (round-robin et élimination directe).
# - **Visu**: Fournit des outils de visualisation pour les compétences et les classements Elo.
#
# ### Modélisation : Sigmoïde
# La probabilité de victoire est calculée à l'aide d'une fonction sigmoïde, ajustée par le taux de hasard du jeu et les différences de niveau (ou Elo) entre les joueurs.
#
# ## Tests et Visualisations
# Nous allons tester les différentes fonctions et visualiser les résultats pour différents jeux et scénarios.

# %% [markdown]
# ## Introduction aux Modélisations
# ### Première Modélisation
# Dans ce modèle, les joueurs sont générés avec une force connue dès leur création. Les rencontres sont simulées en utilisant une fonction sigmoïde pour calculer les probabilités de victoire, en fonction de la différence de force entre les joueurs et du taux de hasard du jeu. Les classements Elo sont mis à jour après chaque match.
#
# ### Deuxième Modélisation
# Dans ce modèle, la force des joueurs est inconnue. Les probabilités de victoire sont calculées en fonction de la différence d'Elo et du taux de hasard du jeu, sans utiliser directement la force réelle des joueurs.

# %% [markdown]
# ## Importation des Modules Nécessaires

# %%
from modele_joueur import *
import numpy as np

# %% [markdown]
# ## Test de la Classe `Joueur`

# %%
# Création d'un joueur
player = Joueur("nom1", "prenom1", 25, [8, 7, 6, 5, 4], [], [], [1500])
player.__str__()

# Calcul de la force du joueur
print("Force du joueur:", player.force_joueur())
# Out:
# Nom : nom1
# Prénom : prenom1
# Age : 25
# Compétences : [8, 7, 6, 5, 4]
# Historique des Elos : [1500]
# Historique des parties : []
# Historique des tournois : []
# Force du joueur: 0.5333333333333333

# %% [markdown]
# ## Test de la Fonction `generer_joueur`

# %%
# Génération d'un joueur aléatoire
random_player = generer_joueur("Random", "Player")
random_player.__str__()
# Out:
# Nom : Random
# Prénom : Player
# Age : 27
# Compétences : [2.7, 3.2, 0.6, 3.3, 2.7]
# Historique des Elos : [1500]
# Historique des parties : []
# Historique des tournois : []

# %% [markdown]
# ## Visualisation des Compétences et des Elo

# %%
# Génération de plusieurs joueurs
players = [generer_joueur(f"Player{i}", f"Test{i}") for i in range(10)]

# Visualisation des compétences
tracer_competences(players)

# Visualisation des classements Elo
tracer_elo(players)
# Out:
# C:\Users\HJ7\new_proj\modele_joueur\visu.py:47: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(elo, color='orange', label='Densité', linewidth=2)

# %% [markdown]
# ## Tests pour la Première Modélisation

# %%
# Génération de joueurs
players_model1 = [generer_joueur(f"Player{i}", f"Test{i}") for i in range(10)]

# Création d'un jeu avec un certain taux de hasard
game_model1 = Jeu("Chess", 0.3)

# Simulation d'un tournoi round-robin
round_robin_results_model1 = tournoi_round_robin(players_model1, game_model1)

# Visualisation des compétences et des classements Elo
tracer_competences(players_model1)
tracer_elo(players_model1)

# %% [markdown]
# ## Tests pour la Deuxième Modélisation

# %%
# Génération de joueurs
players_model2 = [generer_joueur(f"Player{i}", f"Test{i}") for i in range(8)]

# Création d'un jeu avec un taux de hasard élevé
game_model2 = Jeu("Poker", 0.7)

# Simulation d'un tournoi round-robin
round_robin_results_model2 = tournoi_round_robin_modele2(players_model2, game_model2)

# Visualisation des classements Elo
tracer_elo(players_model2)

# %% [markdown]
# ## Simulation de Tournois

# %%
# Création d'un jeu
game = Jeu("Chess", 0.3)

# Simulation d'un tournoi round-robin
round_robin_results = tournoi_round_robin(players, game)
afficher_classement(round_robin_results)

print("\n\n")

# Simulation d'un tournoi à élimination directe
elimination_results = tournoi_eliminatoire(players, game)
afficher_classement(elimination_results)
# Out:
# Classement du tournoi à élimination directe:
# 1. Player32 Test32 - 4628.8936221564145 Elo
# 2. Player81 Test81 - 4518.22004396003 Elo
# 3. Player55 Test55 - 4655.348302440929 Elo
# 4. Player35 Test35 - 4938.648068269504 Elo
# 5. Player13 Test13 - 4917.20515261753 Elo
# 6. Player8 Test8 - 5005.065551022016 Elo
# 7. Player15 Test15 - 4898.769481005186 Elo
# 8. Player25 Test25 - 4761.854490018694 Elo
# 9. Player88 Test88 - 4759.523618339714 Elo
# 10. Player67 Test67 - 4599.639282979431 Elo
# 11. Player99 Test99 - 4810.303752229668 Elo
# 12. Player7 Test7 - 4817.139837740844 Elo
# 13. Player18 Test18 - 5042.24677610025 Elo
# 14. Player73 Test73 - 5238.469194430943 Elo
# 15. Player16 Test16 - 5156.281380021879 Elo
# 16. Player46 Test46 - 5051.1816480427915 Elo
# 17. Player60 Test60 - 4906.995582579298 Elo
# 18. Player45 Test45 - 5042.064159848304 Elo
# 19. Player51 Test51 - 4901.3214161958485 Elo
# 20. Player85 Test85 - 4800.597589163955 Elo
# 21. Player12 Test12 - 4682.135355202365 Elo
# 22. Player4 Test4 - 4559.168457178701 Elo
# 23. Player22 Test22 - 4550.008659468262 Elo
# 24. Player33 Test33 - 4432.919958295124 Elo
# 25. Player41 Test41 - 4386.316152064436 Elo
# 26. Player86 Test86 - 4240.280401974458 Elo
# 27. Player75 Test75 - 4153.091839935185 Elo
# 28. Player53 Test53 - 4044.5595993094475 Elo
# 29. Player78 Test78 - 3910.1847064124527 Elo
# 30. Player50 Test50 - 3874.6507136029295 Elo
# 31. Player96 Test96 - 3854.361511512038 Elo
# 32. Player9 Test9 - 3711.7498291738025 Elo
# 33. Player49 Test49 - 3671.20580606213 Elo
# 34. Player11 Test11 - 3625.60951786102 Elo
# 35. Player95 Test95 - 3368.9363493143405 Elo
# 36. Player20 Test20 - 3462.3742286603765 Elo
# 37. Player74 Test74 - 3217.4258305279154 Elo
# 38. Player70 Test70 - 3190.959768061129 Elo
# 39. Player19 Test19 - 3111.8601205641703 Elo
# 40. Player21 Test21 - 3022.306203736155 Elo
# 41. Player59 Test59 - 2920.9767183091058 Elo
# 100. Player37 Test37 - -2863.4351581354617 Elo
#
#
#
# tour 1:
# Player32 Test32 vs Player1 Test1
# Player61 Test61 vs Player69 Test69
# Player31 Test31 vs Player25 Test25
# Player75 Test75 vs Player39 Test39
# Player2 Test2 vs Player84 Test84
# Player42 Test42 vs Player71 Test71
# Player38 Test38 vs Player44 Test44
# Player70 Test70 vs Player91 Test91
# Player20 Test20 vs Player40 Test40
# Player86 Test86 vs Player82 Test82
# Player88 Test88 vs Player26 Test26
# Player35 Test35 vs Player68 Test68
# Player76 Test76 vs Player87 Test87
# Player7 Test7 vs Player10 Test10
# Player24 Test24 vs Player15 Test15
# Player22 Test22 vs Player17 Test17
# Player19 Test19 vs Player89 Test89
# Player11 Test11 vs Player46 Test46
# Player67 Test67 vs Player65 Test65
# Player98 Test98 vs Player27 Test27
# Player33 Test33 vs Player28 Test28
# Player8 Test8 vs Player57 Test57
# Player59 Test59 vs Player63 Test63
# Player36 Test36 vs Player72 Test72
# Player6 Test6 vs Player74 Test74
# Player60 Test60 vs Player73 Test73
# Player62 Test62 vs Player37 Test37
# Player53 Test53 vs Player48 Test48
# Player93 Test93 vs Player21 Test21
# Player55 Test55 vs Player80 Test80
# Player58 Test58 vs Player5 Test5
# Player50 Test50 vs Player96 Test96
# Player77 Test77 vs Player97 Test97
# Player78 Test78 vs Player94 Test94
# Player52 Test52 vs Player54 Test54
# Player13 Test13 vs Player16 Test16
# Player90 Test90 vs Player95 Test95
# Player3 Test3 vs Player99 Test99
# Player29 Test29 vs Player23 Test23
# Player92 Test92 vs Player81 Test81
# Player51 Test51 vs Player79 Test79
# Player9 Test9 vs Player34 Test34
# Player85 Test85 vs Player30 Test30
# Player83 Test83 vs Player66 Test66
# Player0 Test0 vs Player18 Test18
# Player12 Test12 vs Player56 Test56
# Player45 Test45 vs Player14 Test14
# Player4 Test4 vs Player41 Test41
# Player64 Test64 vs Player47 Test47
# Player43 Test43 vs Player49 Test49
# tour 2:
# Player22 Test22 vs Player99 Test99
# Player98 Test98 vs Player42 Test42
# Player38 Test38 vs Player87 Test87
# Player85 Test85 vs Player97 Test97
# Player61 Test61 vs Player95 Test95
# Player13 Test13 vs Player64 Test64
# Player4 Test4 vs Player51 Test51
# Player20 Test20 vs Player25 Test25
# Player54 Test54 vs Player33 Test33
# Player83 Test83 vs Player74 Test74
# Player2 Test2 vs Player78 Test78
# Player59 Test59 vs Player46 Test46
# Player35 Test35 vs Player72 Test72
# Player67 Test67 vs Player23 Test23
# Player7 Test7 vs Player70 Test70
# Player50 Test50 vs Player81 Test81
# Player58 Test58 vs Player32 Test32
# Player21 Test21 vs Player8 Test8
# Player49 Test49 vs Player75 Test75
# Player45 Test45 vs Player86 Test86
# Player15 Test15 vs Player53 Test53
# Player9 Test9 vs Player12 Test12
# Player18 Test18 vs Player73 Test73
# Player62 Test62 vs Player88 Test88
# Player55 Test55 vs Player19 Test19
# tour 3:
# Player88 Test88 vs Player67 Test67
# Player75 Test75 vs Player12 Test12
# Player46 Test46 vs Player35 Test35
# 99. Player69 Test69 - -2407.8259128352847 Elo
# 100. Player1 Test1 - -2818.412531821537 Elo

# %% [markdown]
# ## Comparaison des Modélisations

# %%
# Comparaison des distributions des classements Elo
tracer_comparaison_evolution_elo(players_model1)
tracer_comparaison_evolution_elo(players_model2)

# %% [markdown]
# ## Évolution des Classements Elo

# %%
# Simulation de plusieurs tournois
for _ in range(10):
    tournoi_round_robin(players, game)

# Visualisation de l'Evolution de l'Elo pour le joueur 1
tracer_evolution_elo(players[0])

# %% [markdown]
# ## Tests pour Différents Jeux avec Variation du Taux de Hasard

# %%
# Création de jeux avec différents taux de hasard
games = [
    Jeu("Jeu Faible Hasard", 0.1),
    Jeu("Jeu Moyen Hasard", 0.5),
    Jeu("Jeu Élevé Hasard", 0.9)
]

# Génération de joueurs
players = [generer_joueur(f"Player{i}", f"Test{i}") for i in range(10)]

# Tests pour chaque jeu
for game in games:
    print(f"\nTests pour {game.nom} avec taux de hasard {game.taux_de_hasard}")

    # Simulation d'un tournoi round-robin
    round_robin_results = tournoi_round_robin(players, game)

    # Visualisation des classements Elo
    tracer_elo(players)

    # Suivi de l'évolution de l'Elo pour un joueur
    tracer_evolution_elo(players[0])
# Out:
# Tests pour Jeu Faible Hasard avec taux de hasard 0.1
# Tests pour Jeu Moyen Hasard avec taux de hasard 0.5
# Tests pour Jeu Élevé Hasard avec taux de hasard 0.9

# %% [markdown]
# ## Visualisation de la corrélation Elo-Force

# %% [markdown]
# ## 1er modèle

# %%
# Création de jeux avec différents taux de hasard
games = [
    Jeu("Jeu Faible Hasard", 0.1),
    Jeu("Jeu Moyen Hasard", 0.5),
    Jeu("Jeu Élevé Hasard", 0.9)
]

# Génération de joueurs
players = [generer_joueur(f"Player{i}", f"Test{i}") for i in range(100)]

# Tests pour chaque jeu
for game in games:
    print(f"\nTests pour {game.nom} avec taux de hasard {game.taux_de_hasard}")

    # Simulation d'un tournoi round-robin
    round_robin_results = tournoi_round_robin(players, game)

    # Visualisation de la corrélation Elo-Force
    tracer_force_elo(players)
# Out:
# Tests pour Jeu Faible Hasard avec taux de hasard 0.1
# Tests pour Jeu Moyen Hasard avec taux de hasard 0.5
# Tests pour Jeu Élevé Hasard avec taux de hasard 0.9

# %% [markdown]
# ## 2eme modèle

# %%
# Création de jeux avec différents taux de hasard
games = [
    Jeu("Jeu Faible Hasard", 0.1),
    Jeu("Jeu Moyen Hasard", 0.5),
    Jeu("Jeu Élevé Hasard", 0.9)
]

# Génération de joueurs
players = [generer_joueur(f"Player{i}", f"Test{i}") for i in range(100)]

# Tests pour chaque jeu
for game in games:
    print(f"\nTests pour {game.nom} avec taux de hasard {game.taux_de_hasard}")

    # Simulation d'un tournoi round-robin
    round_robin_results = tournoi_round_robin_modele2(players, game)

    # Visualisation de la corrélation Elo-Force
    tracer_force_elo(players)
# Out:
# Tests pour Jeu Faible Hasard avec taux de hasard 0.1
# Tests pour Jeu Moyen Hasard avec taux de hasard 0.5
# Tests pour Jeu Élevé Hasard avec taux de hasard 0.9
